# %% [markdown]
# # Linear regression part-2

# %% [markdown]
# In our earlier class we have discussed about the cost function and its importance in lineaer regression. The objective in any regression method is to minimize the cost fucntion. In our previous class we did it manually. However we need a optimization algorithm to do it automatically. The gradient descent algorithm is one of the best optimization method for linear regression problem. Here we will try to understant about this algorithm.

# %%
import numpy as np
from IPython.display import display, Math, Latex
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D
import pylab as plb
from IPython.display import Image, display

# %% [markdown]
# As we discussed, we choosed the sum of square error as a cost function for this problem. Here our objective is to find the minimum value of **C** by adjusting the parameter **a** and **b**. For simplicity let us consider **a = P**1 and **b = P**2

# %%
display(Math(r'C(P_1, P_2) =\frac 1{2m} \sum_{i=1}^m (H_i - Y_i)^2')) # cost function
# Out:
# $$C(P_1, P_2) =\frac 1{2m} \sum_{i=1}^m (H_i - Y_i)^2$$

# %% [markdown]
# ## Gradient descent:

# %% [markdown]
# The equation of gradient descent is as given below

# %%
display(Math(r'P_k = P_k -\alpha\frac{\partial }{\partial P_k}C(P_1,P_2) \ ( for \ k =1 \ and \ k =2)'))
# Out:
# $$P_k = P_k -\alpha\frac{\partial }{\partial P_k}C(P_1,P_2) \ ( for \ k =1 \ and \ k =2)$$

# %% [markdown]
# Here α is the learning rate or the step at which the gradient will descent. For simplicity let us take P2 = 0. The gradient of the cost function J(P1) with respect to P1 can be elastreted as given below. Now if the gradient is positive the value of P1 will decrease(as shown in green arrow). However if the gradient is negative then P1 will increase(as shown in maroon arrow), and eventually it will reach to minima of **J** at a step of α.

# %%
display(Image(filename='Linear Regression Gradnt.png'))

# %% [markdown]
# The learning rate will tells us that how quickly or slowly the optimization process will happen. However their is a trade off between the learning rate and accuracy of the optimization. This can be well explained with this diagram below. Let us suppose one is to step down with a step of two(as shown in red line) then it will not reach the bottom floor. If the step down happen in one steps then it will reach to the bottom floor, however this will take much time compared to two step process. Therefore we have to choose a optimized learning rate that will provide fast and better accuracy.

# %%
display(Image(filename='Learning Rate.png'))

# %% [markdown]
# Now if we expand the equation of the gradient descent as below.

# %%
display(Math(r'P_k = P_k -\alpha\frac{\partial }{\partial P_k}C(P_1,P_2) \ ( for \ k =1 \ and \ k =2)'))
# Out:
# $$P_k = P_k -\alpha\frac{\partial }{\partial P_k}C(P_1,P_2) \ ( for \ k =1 \ and \ k =2)$$

# %% [markdown]
# Where

# %%
display(Math(r'\frac{\partial }{\partial P_k}C(P_1,P_2) =\frac{\partial }{\partial P_k}\frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)^2'))
# Out:
# $$\frac{\partial }{\partial P_k}C(P_1,P_2) =\frac{\partial }{\partial P_k}\frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)^2$$

# %%
display(Math(r'for\ P_1:\ \frac{\partial }{\partial P_1}\frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)^2 = \frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)X^i'))
# Out:
# $$for\ P_1:\ \frac{\partial }{\partial P_1}\frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)^2 = \frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)X^i$$

# %%
display(Math(r'for\ P_2:\ \frac{\partial }{\partial P_2}\frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)^2 = \frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)'))
# Out:
# $$for\ P_2:\ \frac{\partial }{\partial P_2}\frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)^2 = \frac{1}{2m}\sum_{i =1}^{m}(P_2 + P_1X^i-Y^i)$$

# %% [markdown]
# In linear regression, the gradient descent will always find a gloabal minima, since their is no local minima for linear regression. Here we will try to manually impliment the gradient descent algorithm.

# %%
def cost_f(X,Y,P): # X and Y are for the data and P is the parameters for the hypothesis.
    
    H = P[0]*X + P[1]
    
    C = (np.sum(np.square(H - Y)))/2*len(X)
    return C

# %%
def g_d(alpha, X, Y, P, num_itr): # alpha=learning rate, num_itr = number of iteration, P = parameters of hypothesis
    cf = np.zeros((num_itr))
    pplt = np.zeros((2, num_itr))
    for i in range(num_itr):
        p1_new = P[0] - alpha*( np.sum( (P[0]*X + P[1] - Y)*X )  ) / 2*len(X)
        p2_new = P[1] - alpha*( np.sum( (P[0]*X + P[1] - Y) )  ) / 2*len(X)
        
        # Update of new parameters
        P[0] = p1_new
        P[1] = p2_new
        
        cf[i] = cost_f(X,Y,P)
        pplt[0,i] = P[0]
        
        pplt[1,i] = P[1]
    return P, pplt, cf

# %%
P = [0.0, 0.0]
P = np.array(P)

# %%
X = [1, 2, 3, 4, 5]
X = np.array(X)
#X = X/max(X)
Y = [10, 40, 50, 78, 83]
Y = np.array(Y)
#Y = Y/max(Y)

# %%
itr = 2000
alpha = 0.01

# %%
PP, PPlt, CF = g_d(alpha, X, Y, P, itr)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
# Make data.
X = PPlt[0]
Y = PPlt[1]
Z= CF

# %%
plt.plot(X,Z)
plt.show()

# %%
import plotly 
plotly.tools.set_credentials_file(username='mohendra', api_key='XiPZpLL3u0yoNUfmskFh')

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace0 = Scatter(
    x=[1, 2, 3, 4],
    y=[10, 15, 13, 17]
)
trace1 = Scatter(
    x=[1, 2, 3, 4],
    y=[16, 5, 11, 9]
)
data = Data([trace0, trace1])

py.plot(data, filename = 'basic-line')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~mohendra/0 or inside your plot.ly account where it is named 'basic-line'
# 'https://plot.ly/~mohendra/0'

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
from plotly.graph_objs import Scatter, Figure, Layout

plot([Scatter(x=[1, 2, 3], y=[3, 1, 6])])
# Out:
# 'file:///Users/mohendra/Documents/My_Projects/LR/temp-plot.html'

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
# Out:
# <div id="8b2ac2a7-b64b-4035-974d-36895afce3ef" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8b2ac2a7-b64b-4035-974d-36895afce3ef", [{"y": [3, 1, 6], "x": [1, 2, 3]}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
from plotly.graph_objs import *
import numpy as np

x = PPlt[1]
y = CF
iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
       Scatter(x=x, y=y, mode='markers', marker=Marker(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div id="01aa50a4-fc23-4dbb-ac87-4bd5a7c5e860" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("01aa50a4-fc23-4dbb-ac87-4bd5a7c5e860", [{"y": [9065.422498988095, 2475.6749298308714, 961.0982933613452, 610.4811186674311, 526.9159416926697, 504.7222005840959, 496.7286220990334, 492.112802090823, 488.38791735367033, 484.9788349918241, 481.749005806135, 478.66264959677727, 475.7072808625983, 472.87593493129356, 470.1630846507505, 467.5636968513388, 465.0730091062595, 462.68647195474637, 460.3997293438115, 458.20860809790736, 456.10910971161877, 454.09740291728446, 452.1698166624059, 450.3228334034148, 448.5530826850694, 446.85733498952715, 445.23249584289493, 443.67560016827827, 442.1838068749754, 440.75439367393307, 439.3847521099932, 438.0723828018721, 436.81489088117974, 435.6099816221613, 434.4554562541823, 433.34920794931577, 432.2892179777119, 431.27355202373224, 430.30035665612604, 429.36785594581, 428.4743482250748, 427.6182029823084, 426.79785788656767, 426.0118159365692, 425.25864272889686, 424.53696384043997, 423.84546232028634, 423.1828762864933, 422.5479966233512, 421.9396647749352, 421.35677063092515, 420.7982505008249, 420.2630851728955, 419.7502980542532, 419.25895338874057, 418.7881545493179, 418.3370424018593, 417.9047937373674, 417.49061976974673, 417.09376469639096, 416.7135043189632, 416.34914472184687, 416.0000210058584, 415.6654960749107, 415.34495947341145, 415.0378262722785, 414.7435360015362, 414.46155162754445, 414.19135857299636, 413.9324637778968, 413.68439479980276, 413.4466989516927, 413.21894247588193, 413.00070975248195, 412.7916025409611, 412.59123925341834, 412.3992542582431, 412.2152972128945, 412.0390324245853, 411.87013823768973, 411.70830644677653, 411.55324173417966, 411.4046611310915, 411.2622935011884, 411.12587904584905, 410.9951688300635, 410.8699243281651, 410.7499169885594, 410.63492781665104, 410.52474697521694, 410.4191734014814, 410.31801444021306, 410.22108549215375, 410.12820967715925, 410.03921751141684, 409.95394659816674, 409.8722413313488, 409.79395261165337, 409.71893757443064, 409.6470593289898, 409.5781867087939, 409.5121940320997, 409.44896087261236, 409.38837183972055, 409.33031636793265, 409.2746885151063, 409.2213867691253, 409.1703138626536, 409.12137659563837, 409.07448566523374, 409.0295555028372, 408.98650411794193, 408.9452529485146, 408.9057267176337, 408.8678532961199, 408.8315635709124, 408.7967913189476, 408.7634730863134, 408.731548072455, 408.70095801922344, 408.6716471045638, 408.6435618406488, 408.6166509762714, 408.5908654033207, 408.56615806716457, 408.5424838807864, 408.51979964250404, 408.49806395713654, 408.4772371604637, 408.45728124684365, 408.4381597998611, 408.4198379258703, 408.40228219032167, 408.38546055674834, 408.36934232830447, 408.3538980917479, 408.33909966376655, 408.32492003954746, 408.3113333434983, 408.2983147820273, 408.28584059829865, 408.2738880288822, 408.2624352622104, 408.2514613987787, 408.2409464130055, 408.2308711166886, 408.22121712399166, 408.21196681788956, 408.2031033180227, 408.19461044989316, 408.1864727153467, 408.17867526429296, 408.17120386760456, 408.16404489115337, 408.15718527092935, 408.1506124891997, 408.14431455166755, 408.13827996558405, 408.13249771877406, 408.1269572595438, 408.12164847742326, 408.116561684716, 408.11168759882275, 408.1070173252999, 408.10254234163074, 408.09825448167044, 408.09414592074637, 408.0902091613786, 408.08643701959807, 408.082822611837, 408.0793593423674, 408.076040891265, 408.0728612028767, 408.06981447476903, 408.0668951471403, 408.06409789267536, 408.06141760682317, 408.0588493984812, 408.0563885810722, 408.0540306639897, 408.05177134440453, 408.0496064994125, 408.0475321785104, 408.0455445963875, 408.04364012601786, 408.0418152920416, 408.0400667644224, 408.03839135237126, 408.036785998524, 408 ...

# %%
import plotly.plotly as py
from plotly.graph_objs import *

import numpy as np

s = np.linspace(0, 2 * np.pi, 240)
t = np.linspace(0, np.pi, 240)
tGrid, sGrid = np.meshgrid(s, t)

r = 2 + np.sin(7 * sGrid + 5 * tGrid)  # r = 2 + sin(7s+5t)
x = r * np.cos(sGrid) * np.sin(tGrid)  # x = r*cos(s)*sin(t)
y = r * np.sin(sGrid) * np.sin(tGrid)  # y = r*sin(s)*sin(t)
z = r * np.cos(tGrid)                  # z = r*cos(t)

surface = Surface(x=x, y=y, z=z)
data = Data([surface])

layout = Layout(
    title='Parametric Plot',
    scene=Scene(
        xaxis=XAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        yaxis=YAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        zaxis=ZAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        )
    )
)

fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='test')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mohendra/3.embed" height="525px" width="100%"></iframe>

# %%
from IPython.display import Image
Image(url='http://i.imgur.com/PzOz1qc.gif')
# Out:
# <img src="http://i.imgur.com/PzOz1qc.gif"/>
